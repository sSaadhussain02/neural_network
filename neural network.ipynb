# %% [markdown]
# # **neural network**

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt

# Load the dataset
data = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = data.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Create the neural network
model = keras.Sequential([
  keras.layers.Flatten(input_shape=(28, 28)),
  keras.layers.Dense(128, activation='relu'),
  keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# Make predictions
predictions = model.predict(x_test)

# Display the predictions with images
for i in range(10):
  # Plot the image
  plt.imshow(x_test[i], cmap='gray')
  plt.axis('off')
  plt.show()

  # Get the predicted label
  predicted_label = predictions[i].argmax()

  # Print the predicted label
  print('Prediction for image {}: {}'.format(i, predicted_label))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2618 - accuracy: 0.9248
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1127 - accuracy: 0.9675
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0767 - accuracy: 0.9768
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0571 - accuracy: 0.9825
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0443 - accuracy: 0.9863
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0339 - accuracy: 0.9896
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0269 - accuracy: 0.9915
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0216 - accuracy: 0.9934
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0186 - accuracy: 0.9937
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0146 - accuracy: 0.9956
# Test loss: 0.08672934025526047
# Test accuracy: 0.9764999747276306
# 313/313 [==============================] - 1s 2ms/step
# Prediction for image 0: 7
# Prediction for image 1: 2
# Prediction for image 2: 1
# Prediction for image 3: 0
# Prediction for image 4: 4
# Prediction for image 5: 1
# Prediction for image 6: 4
# Prediction for image 7: 9
# Prediction for image 8: 5
# Prediction for image 9: 9
